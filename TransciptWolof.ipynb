# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/anaconda3/lib/python3.9/site-packages (4.24.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: packaging>=20.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: requests in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (1.21.5)
# Requirement already satisfied: filelock in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from transformers) (0.10.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests->transformers) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wolof   #importation de la bibliotheque wolof de abdouaziz
# Out:
# Requirement already satisfied: wolof in /usr/local/anaconda3/lib/python3.9/site-packages (0.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/anaconda3/lib/python3.9/site-packages (4.5.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/anaconda3/lib/python3.9/site-packages (from gdown) (4.11.1)
# Requirement already satisfied: filelock in /usr/local/anaconda3/lib/python3.9/site-packages (from gdown) (3.6.0)
# Requirement already satisfied: six in /usr/local/anaconda3/lib/python3.9/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/anaconda3/lib/python3.9/site-packages (from gdown) (4.64.0)
# Requirement already satisfied: requests[socks] in /usr/local/anaconda3/lib/python3.9/site-packages (from gdown) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !gdown --id 1wRiwaQmGi3dotcPgs7-vKt-o9JBN4I-n
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1wRiwaQmGi3dotcPgs7-vKt-o9JBN4I-n
# To: /Users/macos/Documents/PROJETS/AYI-TEKK-Challenge-PAS/ASR_WOLOF_data_dev_wav_03_WOL_03_lect_0004.wav
# 100%|█████████████████████████████████████████| 120k/120k [00:00<00:00, 285kB/s]

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/anaconda3/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (1.21.5)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: setuptools in /usr/local/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wolof import Speech2Text # from wolof we import Swpeech2Text 
from IPython.display import Audio

# %%
asr = Speech2Text(model_name="abdouaziiz/wav2vec2-xls-r-300m-wolof") #chargement du modéle

# %%
pip install speechrecognition #installation de speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in /usr/local/anaconda3/lib/python3.9/site-packages (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/anaconda3/lib/python3.9/site-packages (22.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pyaudio
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2022.05=py39_0
#   - defaults/osx-64::bcrypt==3.2.0=py39h9ed2024_0
#   - defaults/osx-64::scrapy==2.6.1=py39hecd8cb5_0
#   - defaults/osx-64::twisted==22.2.0=py39hca72f7f_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/anaconda3
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.05  |           py39_0           6 KB  anaconda
#     anaconda-custom            |           py39_1           4 KB
#     ca-certificates-2022.4.26  |       hecd8cb5_0         132 KB  anaconda
#     certifi-2022.6.15          |   py39hecd8cb5_0         157 KB  anaconda
#     openssl-1.1.1o             |       hca72f7f_0         3.5 MB  anaconda
#     pip-21.2.4                 |   py39hecd8cb5_0         2.0 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  anaconda/osx-64::_anaconda_depends-2022.05-py39_0 None
#   pip                anaconda/osx-64::pip-21.2.4-py39hecd8cb5_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.3.29-hecd8cb5_1 --> 2022.4.26-hecd8cb5_0 None
#   certifi                          2021.10.8-py39hecd8cb5_2 --> 2022.6.15-py39hecd8cb5_0 None
#   openssl                                 1.1.1n-hca72f7f_0 --> 1.1.1o-hca72f7f_0 None
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.05-py39_0 --> custom-py39_1 None
#
#
#
# Downloading and Extracting Packages
# anaconda-custom      | 4 KB      | ##################################### | 100%
# _anaconda_depends-20 | 6 KB      | ##################################### | 100%
# ca-certificates-2022 | 132 KB    | ##################################### | 100%
# openssl-1.1.1o       | 3.5 MB    | ##################################### | 100%
# pip-21.2.4           | 2.0 MB    | ##################################### | 100%
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: \ WARNING conda.core.path_actions:verify(962): Unable to create environments file. Path not writable.
#   environment location: /Users/macos/.conda/environments.txt
#
# done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio # installation de pyaudio
# Out:
# Requirement already satisfied: pyaudio in /usr/local/anaconda3/lib/python3.9/site-packages (0.2.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr #importation de speechRecognition
r = sr.Recognizer()
micro = sr.Microphone() #utilisation du microphone pour l'enregistrement audio
with micro as source:
    print ("speak")
    audio_data = r.listen(source)  #récuperation de l'audio via le microphone
    print("end")

Audio(audio_data)  

#self.audio_data = Audio._make_wav(audio_data, rate=sr, normalize=True)

prediction = asr(audio_data)  #transcription de l'audio en texte
prediction

# %%
from wolof import Speech2Text

#asr = Speech2Text(model_name="abdouaziiz/wav2vec2-xls-r-300m-wolof")

audio_file = "ASR_WOLOF_data_dev_wav_03_WOL_03_lect_0004.wav"
#audio_file = "recording1.wav"

#prediction = asr.predict(audio_file)

prediction = asr(audio_file)  #transcription de l'audio en texte
prediction
# Out:
# 'ndaxam mu ngi ne cocc ak téeméeri atam'

# %%
import speech_recognition as sr #importation de speechRecognition
import numpy as np
import librosa

r = sr.Recognizer()
micro = sr.Microphone() #utilisation du microphone pour l'enregistrement audio
with micro as source:
    print ("speak")
    audio_data = r.listen(source)  #récuperation de l'audio via le microphone
    print("end")
Audio(audio_data)
